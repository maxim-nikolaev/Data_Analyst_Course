# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Цель-исследования:" data-toc-modified-id="Цель-исследования:-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Цель исследования:</a></span><ul class="toc-item"><li><span><a href="#Столбцы-данных" data-toc-modified-id="Столбцы-данных-0.0.1.1"><span class="toc-item-num">0.0.1.1&nbsp;&nbsp;</span>Столбцы данных</a></span></li></ul></li><li><span><a href="#Шаг-1.-Открытие-файла-с-данными-и-изучение-общей-информации" data-toc-modified-id="Шаг-1.-Открытие-файла-с-данными-и-изучение-общей-информации-0.0.2"><span class="toc-item-num">0.0.2&nbsp;&nbsp;</span>Шаг 1. Открытие файла с данными и изучение общей информации</a></span></li><li><span><a href="#Шаг-2.-Подготовка-данных" data-toc-modified-id="Шаг-2.-Подготовка-данных-0.0.3"><span class="toc-item-num">0.0.3&nbsp;&nbsp;</span>Шаг 2. Подготовка данных</a></span></li><li><span><a href="#Шаг-3.-Провести-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Провести-исследовательский-анализ-данных-0.0.4"><span class="toc-item-num">0.0.4&nbsp;&nbsp;</span>Шаг 3. Провести исследовательский анализ данных</a></span></li><li><span><a href="#Шаг-4.-Составить-портрет-потребителя-каждого-региона" data-toc-modified-id="Шаг-4.-Составить-портрет-потребителя-каждого-региона-0.0.5"><span class="toc-item-num">0.0.5&nbsp;&nbsp;</span>Шаг 4. Составить портрет потребителя каждого региона</a></span></li><li><span><a href="#Шаг-5.-Провести-исследование-статистических-показателей" data-toc-modified-id="Шаг-5.-Провести-исследование-статистических-показателей-0.0.6"><span class="toc-item-num">0.0.6&nbsp;&nbsp;</span>Шаг 5. Провести исследование статистических показателей</a></span></li><li><span><a href="#Шаг-6.-Проверка-гипотез" data-toc-modified-id="Шаг-6.-Проверка-гипотез-0.0.7"><span class="toc-item-num">0.0.7&nbsp;&nbsp;</span>Шаг 6. Проверка гипотез</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-0.0.8"><span class="toc-item-num">0.0.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#1.Предобработка-данных" data-toc-modified-id="1.Предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><a name="1" rel="nofollow">1.Предобработка данных</a></a></span></li><li><span><a href="#-2.-Исследовательский-анализ-данных" data-toc-modified-id="-2.-Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><a name="2" rel="nofollow"> 2. Исследовательский анализ данных</a></a></span></li><li><span><a href="#3.-Портрет-пользователя" data-toc-modified-id="3.-Портрет-пользователя-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><a name="3" rel="nofollow">3. Портрет пользователя</a></a></span></li><li><span><a href="#-4.-Исследование-статистических-показателей." data-toc-modified-id="-4.-Исследование-статистических-показателей.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><a name="4" rel="nofollow"> 4. Исследование статистических показателей.</a></a></span></li><li><span><a href="#5.-Проверка-гипотез-" data-toc-modified-id="5.-Проверка-гипотез--5"><span class="toc-item-num">5&nbsp;&nbsp;</span><a name="5" rel="nofollow">5. Проверка гипотез </a></a></span></li><li><span><a href="#6.-Выводы" data-toc-modified-id="6.-Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><a name="6" rel="nofollow">6. Выводы</a></a></span></li></ul></div>

# %% [markdown]
# ### Цель исследования:

# %% [markdown]
# Необходимо выявить определяющие популярность марки вина закономерности и попытаться выяснить, что можно предложить покупателям вина при выборе вина. Это позволит сделать ставку на потенциально популярный продукт и спланировать например рекламную кампанию для интернет-магазинов, осуществляющих продажи вина.
#
# Выполнение задачи предполагает:<br>
# <a href=#1>1.  Предобработку данных</a><br>
# <a href=#2>2.  Исследовательский анализ данных</a><br>
# <a href=#3>3.  Составление портрета пользователя.</a><br>
# <a href=#4>4.  Исследование статистических показателей.</a><br>
# <a href=#5>5.  Проверку гипотез.</a><br>
# <a href=#6>6.  Выводы</a><br>
#
# Цель этого проекта — выявить, какие признаки больше всего влияют на рейтинг вина. Для анализа используется набор данных из Kaggle, крупнейшего в мире сообщества специалистов по данным и машинному обучению. Набор данных состоит из 10 признаков (2 числовых признака и 8 категориальных признаков).

# %% [markdown]
# #### Столбцы данных
#
# - Страна(country) - страна происхождения вина.
# - Описание(description) — описание вкусового профиля вина.
# - Обозначение(designation) - виноградник, откуда берется виноград для вина.
# - Баллы(points) - количество баллов на которое критик журнала Wine Enthusiast оценил вино по шкале от 1 до 100.
# - Цена(price) - стоимость одной бутылки вина.
# - Провинция(province) - провинция или штат, из которого произведено вино.
# - Регион 1(region_1) — зона виноделия в провинции или штате (например, Rogue Valley в Oregon).
# - Регион 2(region_2) — (не обязательно) более конкретный регион в винодельческой области (например, Southern Oregon	 в Rogue Valley).
# - Разновидность(variety) — сорт винограда, из которого делают вино (например, Pinot Noir).
# - Винодельня(winery)  — винодельня, производящая вино (например, Deer Creek).

# %% [markdown]
# ### Шаг 1. Открытие файла с данными и изучение общей информации
#
#
#
# ### Шаг 2. Подготовка данных
#
# * Заменить названия столбцов (привести к нижнему регистру).
# * Преобразовать данные в нужные типы. Описать, в каких столбцах заменили тип данных и почему.
# * Обработать пропуски при необходимости.
# * Объяснить, почему заполнили пропуски определённым образом или почему не стали это делать.
# * Описать причины, которые могли привести к пропускам.
# * Посчитать среднии цены для каждой страны.
# * Внести новый столбец "Континенты"
# country_to_continent = {<br>
#     'Italy':'Europe', <br>
#     'Portugal':'Europe', <br>
#     'US':'North America', <br>
#     'Spain':'Europe',<br>
#     'France':'Europe',<br>
#     'Germany':'Europe',<br>
#     'Argentina':'Latin America', <br>
#     'Chile':'Latin America', <br>
#     'Australia': 'Oceania', <br>
#     'Austria': 'Europe', <br>
#     'South Africa': 'Africa',<br>
#     'New Zealand': 'Oceania', <br>
#     'Israel': 'Asia', <br>
#     'Hungary':'Europe', <br>
#     'Greece':'Europe',<br>
#     'Romania':'Europe', <br>
#     'Mexico':'Latin America',<br>
#     'Canada':'North America',<br>
#     'Turkey': 'Asia',<br>
#     'Czech Republic': 'Europe',<br>
#     'Slovenia': 'Europe',<br>
#     'Luxembourg': 'Europe',<br>
#     'Croatia': 'Europe',<br>
#     'Georgia':'Europe', <br>
#     'Uruguay': 'Latin America',<br>
#     'England': 'Europe',<br>
#     'Lebanon': 'Asia', <br>
#     'Serbia': 'Europe', <br>
#     'Brazil': 'Latin America',<br>
#     'Moldova': 'Europe', <br>
#     'Morocco':'Africa',<br>
#     'Peru':'Latin America',<br>
#     'India':'Asia', <br>
#     'Bulgaria':'Europe',<br>
#     'Cyprus': 'Europe',<br>
#     'Armenia':'Asia',<br>
#     'Switzerland':'Europe',<br>
#     'Bosnia and Herzegovina':'Europe',<br>
#     'Ukraine':'Europe',<br>
#     'Slovakia':'Europe', <br>
#     'Macedonia':'Europe',<br>
#     'China':'Asia',<br>
#     'Egypt':'Africa'<br>
#     }<br>
#
# ### Шаг 3. Провести исследовательский анализ данных
#
# * Определить, какие сорта лидируют по рейтингам. Найти популярные сорта по региону.
# * Выбрать сорта с наибольшими ценами. Для каждого региона найдите среднюю цену вина.
# * Определить, популярные сорта вина в бюджетном сегменте.
# * Определить, какие сорта вина лидируют по рейтингам.
# * Построить график «ящик с усами» по рейтингам в разбивке по странам, по сортам вина.
# * Выявить закономерность влияния на цену цвета и рейтинга. Построить диаграмму рассеяния и посчитать корреляцию.
#
#
# ### Шаг 4. Составить портрет потребителя каждого региона
#
# Определить для пользователя каждого континента :
# * Самые популярные сорта (топ-5).
# * Влияет ли рейтинг на цены по регионам?
#
# ### Шаг 5. Провести исследование статистических показателей
#
# * Выполнить подсчитать среднего количества, дисперсии и стандартного отклонения для цен на продукт различных регионов. Построить гистограммы. Описать распределения.
# * Построить линейную регрессию зависимости между ценой продукта и его рейтингом.
#
# ### Шаг 6. Проверка гипотез
#
# * H0: Средние пользовательские рейтинги красного и белого вина одинаковые.
# * H1:Средние пользовательские рейтинги красного и белого вина разные.
#
#
# * H0:Средние пользовательские рейтинги двух популярных сортов вина одинаковые.
# * H1:Средние пользовательские рейтинги двух популярных сортов вина разные.
#
#
# * H0:Средние пользовательские рейтинги двух континентов одинаковые.
# * H1:Средние пользовательские рейтинги двух континентов разные.
#
# Задать самостоятельно пороговое значение alpha.
#
#
# ### Вывод

# %% [markdown]
# #  <a name="1">1.Предобработка данных</a>

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

import scipy.stats as st
# импорт библиотеки warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_csv('wine_reviews.csv')
df
# Out:
#       country                                        description  \
# 0          US  With a delicate, silky mouthfeel and bright ac...
# 1       Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2      France  The great dominance of Cabernet Sauvignon in t...
# 3       Italy  The modest cherry, dark berry and black tea no...
# 4          US  Exceedingly light in color, scent and flavor, ...
# ...       ...                                                ...
# 19995  France  Firm wine, with tannins to match the chunky st...
# 19996      US  The vineyard is on the Napa side of Carneros. ...
# 19997   Italy  Lighea is a terrific wine and an excellent pai...
# 19998   Italy  Organically farmed Cannonau grapes deliver sma...
# 19999      US  Grown on the Sonoma side of the appellation, i...
#
#            designation  points  price           province  \
# 0                  NaN      86   23.0         California
# 1              D'Alceo      96  275.0            Tuscany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      20000 non-null  object
#  1   description  20000 non-null  object
#  2   designation  13999 non-null  object
#  3   points       20000 non-null  int64
#  4   price        18198 non-null  float64
#  5   province     20000 non-null  object
#  6   region_1     16543 non-null  object
#  7   region_2     8058 non-null   object
#  8   variety      20000 non-null  object
#  9   winery       20000 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# Количество значений в столбцах различается. Это говорит о том, что в данных есть пустые значения. Признак points и price числовые. С помощью библиотеки seaborn построим тепловую карту для визуализации данных.

# %%
colours = ['#993366', '#FFFF00']
sns.heatmap(df.isnull(), cmap=sns.color_palette(colours))
# Decorations
plt.title('Матрица пропущенных значений набора данных', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.figtext(0.5, -0.2, "Рисунок 1. - Матрица пропущенных значений набора данных")
plt.show()

# %%
MissingValue = df.isnull().sum().sort_values(ascending = False)
Percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
MissingData = pd.concat([MissingValue, Percent], axis=1, keys=['MissingValue', 'Percent'])
MissingData
# Out:
#              MissingValue  Percent
# region_2            11942   59.710
# designation          6001   30.005
# region_1             3457   17.285
# price                1802    9.010
# country                 0    0.000
# description             0    0.000
# points                  0    0.000
# province                0    0.000
# variety                 0    0.000
# winery                  0    0.000

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df['region_2'].unique()
# Out:
# array(['Central Coast', nan, 'Southern Oregon', 'Mendocino/Lake Counties',
#        'Sonoma', 'Willamette Valley', 'Oregon Other', 'California Other',
#        'Columbia Valley', 'North Coast', 'Sierra Foothills',
#        'Napa-Sonoma', 'Napa', 'Long Island', 'Finger Lakes',
#        'Central Valley', 'Washington Other', 'New York Other',
#        'South Coast'], dtype=object)

# %% [markdown]
# Удаляем и обрабатываем пропуски
# Вывод:
# 1. Значительные данные(60 %) пропущены в столбце region_2. Столбец region_2  необходимо удалить;
# 2. В столбце price не более 10% пропусков. Если мы удалим все записи с отсутствующими ценами,
# останется 90,99% набора данных. Мы можем смело отбрасывать записи с отсутствующими
# значениями и не влиять на результаты кардинально;
# 3. Оставим region_1 и designation без изменения.

# %%
df = df.drop(columns = ["region_2"])

# %%
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1                   variety  \
# 0      86   23.0  California     Central Coast                Pinot Noir
# 1      96  275.0     Tuscany           Toscana                 Red Blend
# 2      91   40.0    Bordeaux        Haut-Médoc  Bordeaux-style Red Blend
# 3      81   15.0     Tuscany  Chianti Classico                Sangiovese
# 4      83   25.0      Oregon      Rogue Valley                Pinot Noir
#
#                   winery
# 0        MacMurray Ranch
# 1  Castello dei Rampolla
# ...

# %% [markdown]
# В столбце price не более 10% пропусков. Мы можем смело отбрасывать записи с отсутствующими значениями.

# %%
df = df.dropna(axis='index', how='any', subset=['price'])
df.count()
# Out:
# country        18198
# description    18198
# designation    12637
# points         18198
# price          18198
# province       18198
# region_1       15033
# variety        18198
# winery         18198
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# country           0
# description       0
# designation    5561
# points            0
# price             0
# province          0
# region_1       3165
# variety           0
# winery            0
# dtype: int64

# %% [markdown]
# Добавляем столбец цвет вина 'color'

# %%
color = {
"Chardonnay": "white",
"Pinot Noir": "red",
"Cabernet Sauvignon": "red",
"Red Blend": "red",
"Bordeaux-style Red Blend": "red",
"Sauvignon Blanc": "white",
"Syrah": "red",
"Riesling": "white",
"Merlot": "red",
"Zinfandel": "red",
"Sangiovese": "red",
"Malbec": "red",
"White Blend": "white",
"Rosé": "other",
"Tempranillo": "red",
"Nebbiolo": "red",
"Portuguese Red": "red",
"Sparkling Blend": "other",
"Shiraz": "red",
"Corvina, Rondinella, Molinara": "red",
"Rhône-style Red Blend": "red",
"Barbera": "red",
"Pinot Gris": "white",
"Viognier": "white",
"Bordeaux-style White Blend": "white",
"Champagne Blend": "other",
"Port": "red",
"Grüner Veltliner": "white",
"Gewürztraminer": "white",
"Portuguese White": "white",
"Petite Sirah": "red",
"Carmenère": "red"
}
df['color']= df['variety'].map(color)
df = df.dropna(axis='index', how='any', subset=['color'])

# %% [markdown]
# Добавляем столбец части света country_to_continent

# %%
country_to_continent = {
'Italy':'Europe',
'Portugal':'Europe',
'US':'North America',
'Spain':'Europe',
'France':'Europe',
'Germany':'Europe',
'Argentina':'Latin America',
'Chile':'Latin America',
'Australia': 'Oceania',
'Austria': 'Europe',
'South Africa': 'Africa',
'New Zealand': 'Oceania',
'Israel': 'Asia',
'Hungary':'Europe',
'Greece':'Europe',
'Romania':'Europe',
'Mexico':'Latin America',
'Canada':'North America',
'Turkey': 'Asia',
'Czech Republic': 'Europe',
'Slovenia': 'Europe',
'Luxembourg': 'Europe',
'Croatia': 'Europe',
'Georgia':'Europe',
'Uruguay': 'Latin America',
'England': 'Europe',
'Lebanon': 'Asia',
'Serbia': 'Europe',
'Brazil': 'Latin America',
'Moldova': 'Europe',
'Morocco':'Africa',
'Peru':'Latin America',
'India':'Asia',
'Bulgaria':'Europe',
'Cyprus': 'Europe',
'Armenia':'Asia',
'Switzerland':'Europe',
'Bosnia and Herzegovina':'Europe',
'Ukraine':'Europe',
'Slovakia':'Europe',
'Macedonia':'Europe',
'China':'Asia',
'Egypt':'Africa'
}

# %%
df['country_to_continent'] = df['country'].map(country_to_continent)
df = df.dropna(axis='index', how='any', subset=['country_to_continent'])

# %%
df.count()
# Out:
# country                 15040
# description             15040
# designation             10526
# points                  15040
# price                   15040
# province                15040
# region_1                12365
# variety                 15040
# winery                  15040
# color                   15040
# country_to_continent    15040
# dtype: int64

# %%
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1                   variety  \
# 0      86   23.0  California     Central Coast                Pinot Noir
# 1      96  275.0     Tuscany           Toscana                 Red Blend
# 2      91   40.0    Bordeaux        Haut-Médoc  Bordeaux-style Red Blend
# 3      81   15.0     Tuscany  Chianti Classico                Sangiovese
# 4      83   25.0      Oregon      Rogue Valley                Pinot Noir
#
#                   winery color country_to_continent
# ...

# %%
print(df.isnull().sum())
# Out:
# country                    0
# description                0
# designation             4514
# points                     0
# price                      0
# province                   0
# region_1                2675
# variety                    0
# winery                     0
# color                      0
# country_to_continent       0
# dtype: int64

# %% [markdown]
# Работа с дубликатами

# %%
df[df.duplicated()].head()
# Out:
#            country                                        description  \
# 738   South Africa  This Chard might be unwooded, but it's not sho...
# 1069        France  A bright, fruity wine that has black currant j...
# 1312            US  What a difference from Borghese's regular Char...
# 1363     Australia  High-toned yet refreshing, offering up petrole...
# 1393         Italy  This elegant Superiore expression of Barbera d...
#
#            designation  points  price          province  \
# 738   Fantail Unwooded      86   12.0      Western Cape
# 1069           Classic      85   14.0  Southwest France
# 1312           Reserve      88   18.0          New York
# 1363   Vineyard Select      86   17.0   South Australia
# 1393               NaN      89   24.0          Piedmont
#
#                        region_1          variety            winery  color  \
# 738                         NaN       Chardonnay         Morgenhof  white
# ...

# %%
df.drop_duplicates()
# Out:
#             country                                        description  \
# 0                US  With a delicate, silky mouthfeel and bright ac...
# 1             Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2            France  The great dominance of Cabernet Sauvignon in t...
# 3             Italy  The modest cherry, dark berry and black tea no...
# 4                US  Exceedingly light in color, scent and flavor, ...
# ...             ...                                                ...
# 19991  South Africa  Muscular spice, deep red berry and blackberry ...
# 19993        France  A beautifully elegant wine, wearing its fresh ...
# 19994            US  A little too strong in feline spray character,...
# 19996            US  The vineyard is on the Napa side of Carneros. ...
# 19999            US  Grown on the Sonoma side of the appellation, i...
#
#                  designation  points  price      province          region_1  \
# ...

# %%
df.duplicated().value_counts(normalize=False)
# Out:
# False    14200
# True       840
# dtype: int64

# %%
df.count()
# Out:
# country                 15040
# description             15040
# designation             10526
# points                  15040
# price                   15040
# province                15040
# region_1                12365
# variety                 15040
# winery                  15040
# color                   15040
# country_to_continent    15040
# dtype: int64

# %% [markdown]
# Удалим дубликаты

# %%
df=df.drop_duplicates(keep=False)
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1                   variety  \
# 0      86   23.0  California     Central Coast                Pinot Noir
# 1      96  275.0     Tuscany           Toscana                 Red Blend
# 2      91   40.0    Bordeaux        Haut-Médoc  Bordeaux-style Red Blend
# 3      81   15.0     Tuscany  Chianti Classico                Sangiovese
# 4      83   25.0      Oregon      Rogue Valley                Pinot Noir
#
#                   winery color country_to_continent
# ...

# %%
df.count()
# Out:
# country                 13387
# description             13387
# designation              9363
# points                  13387
# price                   13387
# province                13387
# region_1                11017
# variety                 13387
# winery                  13387
# color                   13387
# country_to_continent    13387
# dtype: int64

# %%
df.duplicated().value_counts(normalize=True)
# Out:
# False    1.0
# dtype: float64

# %% [markdown]
# Все строки дубликаты удалены

# %% [markdown]
# #  <a name="2"> 2. Исследовательский анализ данных</a>

# %% [markdown]
# Основные задачи этапа: Определить, какие сорта лидируют по рейтингам. Найти популярные сорта по региону. Выбрать сорта с наибольшими ценами. Для каждого региона найдите среднюю цену вина. Определить, популярные сорта вина в бюджетном сегменте. Определить, какие сорта вина лидируют по рейтингам. Построить график «ящик с усами» по рейтингам в разбивке по странам, по сортам вина. Выявить закономерность влияния на цену цвета и рейтинга. Построить диаграмму рассеяния и посчитать корреляцию. Рассмотрим важные признаки датафрейма и определим, какие сорта лидируют и популярные по рейтингам

# %%
df.describe()
# Out:
#              points         price
# count  13387.000000  13387.000000
# mean      87.889071     34.803093
# std        3.287602     42.991402
# min       80.000000      5.000000
# 25%       86.000000     16.000000
# 50%       88.000000     25.000000
# 75%       90.000000     41.000000
# max      100.000000   2300.000000

# %% [markdown]
# Country

# %%
df["country"].describe()
# Out:
# count     13387
# unique       31
# top          US
# freq       6628
# Name: country, dtype: object

# %% [markdown]
# В наборе данных встречается 31 страна.Самая частая страна США. Она встречается 13387 раз.

# %%
df_country = df['country'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country','counts']
fig, ax = plt.subplots(figsize=(10,12));
sns.barplot(data = df_country, x='country',y='counts',ax=ax).set_title('Количество образцов по каждой стране')
plt.figtext(0.2, 0, "Рисунок 2. - Распределение по странам ",fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# Безусловный лидер США

# %%
df['country'].value_counts().head(10).plot(kind='pie', stacked=True, figsize=(20, 10));
plt.title("Количество образцов по каждой стране",fontsize=15)
plt.xlabel('Рисунок 3. - Распределение по странам',fontsize=15)
plt.ylabel('country',fontsize=10);

# %% [markdown]
# В наборе данных к данному проекту США занимает более 50%, далее идет Франция, Италия, Чили. Такая тенденция может быть объяснена тем, что набор данных был подготовлоен журналом из США. Не отображена полная статистика из Китая и России. Эти две страны являются крупными производителями и потребителями вина в мире.

# %% [markdown]
# Выведем ТОП 10 наиболее часто встречающихся стран в наборе данных

# %%
df['country'].value_counts().to_frame().head(10)
# Out:
#              country
# US              6628
# France          1493
# Italy           1350
# Chile            654
# Spain            541
# Argentina        536
# Australia        466
# Portugal         443
# New Zealand      346
# Germany          285

# %% [markdown]
# В наборе данных встречается 31 страна.Самая часта страна США она встречается 6628 раз.

# %% [markdown]
# country_to_continent

# %%
df["country_to_continent"].describe()
# Out:
# count             13387
# unique                6
# top       North America
# freq               6645
# Name: country_to_continent, dtype: object

# %%
df_country = df['country_to_continent'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country_to_continent','counts']
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_country, x='country_to_continent',y='counts',ax=ax).set_title('Количество образцов по каждому континенту')
plt.figtext(0.3, -0.1, "Рисунок 4. - Распределение по континентам ", fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# Лидеры США и Европа

# %%
df_country
# Out:
#   country_to_continent  counts
# 0        North America    6645
# 1               Europe    4440
# 2        Latin America    1206
# 3              Oceania     812
# 4               Africa     212
# 5                 Asia      72

# %% [markdown]
# Для данного набора данных лидером среди континентов является Северная Америка, на втором месте Европа.

# %% [markdown]
# designation(описание вкусового профиля вина)

# %%
df.designation.value_counts()[:10]
# Out:
# Reserve           283
# Estate            182
# Reserva           175
# Estate Grown       53
# Riserva            50
# Estate Bottled     43
# Brut               39
# Old Vine           35
# Dry                34
# Gran Reserva       27
# Name: designation, dtype: int64

# %%
df["designation"].describe()
# Out:
# count        9363
# unique       6473
# top       Reserve
# freq          283
# Name: designation, dtype: object

# %% [markdown]
# winery

# %%
df.winery.describe()
# Out:
# count               13387
# unique               5664
# top       Williams Selyem
# freq                   46
# Name: winery, dtype: object

# %% [markdown]
# Количество виноделен использующих самое большое число сортов винограда

# %%
grapes = df[["winery", "variety"]].groupby(by = "winery").count()
max_num = max(grapes["variety"])
min_num = min(grapes["variety"])
max_num
# Out:
# 46

# %% [markdown]
# Количество виноделен использующих самое маленькое число сортов винограда

# %%
min_num
# Out:
# 1

# %% [markdown]
# Провинции (province)

# %%
df.province.describe()
# Out:
# count          13387
# unique           254
# top       California
# freq            4806
# Name: province, dtype: object

# %%
df.province.value_counts()[:10]
# Out:
# California          4806
# Washington          1004
# Tuscany              553
# Oregon               488
# Mendoza Province     459
# Burgundy             399
# Northern Spain       295
# Bordeaux             289
# South Australia      283
# Piedmont             261
# Name: province, dtype: int64

# %% [markdown]
# Лидеры California и Washington

# %% [markdown]
# Variety

# %%
df.variety.describe()
# Out:
# count          13387
# unique            32
# top       Pinot Noir
# freq            1660
# Name: variety, dtype: object

# %%
df['variety'].nunique()
# Out:
# 32

# %% [markdown]
# Согласно набору данных, существует 32 вида винограда

# %% [markdown]
# points

# %%
df["points"].describe()
# Out:
# count    13387.000000
# mean        87.889071
# std          3.287602
# min         80.000000
# 25%         86.000000
# 50%         88.000000
# 75%         90.000000
# max        100.000000
# Name: points, dtype: float64

# %% [markdown]
# Построим столбчатую диаграмму показывающую количество вин для каждого рейтинга

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.xlabel("Рейтинг",fontsize=15)
plt.ylabel("Количество вина",fontsize=15)
plt.title("Количество вина для каждого рейтинга",fontsize=20)
df.groupby(['points']).count()['description'].plot(ax=ax, kind='bar')
plt.figtext(0.3, 0, "Рисунок 5. - Гистограмма частоты признака Points ",fontsize=20)
plt.show()

# %% [markdown]
# Определим средний рейтинг в наборе данных

# %%
avg_rating = df["points"].mean()
avg_rating
# Out:
# 87.88907148726376

# %% [markdown]
# В среднем рейтинг вина составляет 87.88 баллов для данного признака. внесем классификацию на хорошие вина(вина где рейтинг выше среднего)

# %%
def GoodRating(row):
    if row['points'] >= 88:
        val = 1
    else:
        val = 0
    return(val)
df['GoodR'] = df.apply(GoodRating, axis=1)
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1                   variety  \
# 0      86   23.0  California     Central Coast                Pinot Noir
# 1      96  275.0     Tuscany           Toscana                 Red Blend
# 2      91   40.0    Bordeaux        Haut-Médoc  Bordeaux-style Red Blend
# 3      81   15.0     Tuscany  Chianti Classico                Sangiovese
# 4      83   25.0      Oregon      Rogue Valley                Pinot Noir
#
#                   winery color country_to_continent  GoodR
# ...

# %%
dd=df.loc[df['GoodR'] == 0] 
dd.head()
# Out:
#    country                                        description  \
# 0       US  With a delicate, silky mouthfeel and bright ac...
# 3    Italy  The modest cherry, dark berry and black tea no...
# 4       US  Exceedingly light in color, scent and flavor, ...
# 9       US  A soft, round Merlot made from what tastes lik...
# 13  France  This is a wine with good, dense and red fruit,...
#
#                 designation  points  price    province          region_1  \
# 0                       NaN      86   23.0  California     Central Coast
# 3                       NaN      81   15.0     Tuscany  Chianti Classico
# 4                       NaN      83   25.0      Oregon      Rogue Valley
# 9   Larry Venturi Vineyards      85   35.0  California         Mendocino
# 13                      NaN      87   13.0    Bordeaux          Bordeaux
#
#                      variety              winery color country_to_continent  \
# ...

# %%
country_price = dd.groupby(['variety',]).mean()['points'].sort_values(ascending=False).to_frame()
country_price.head()
# Out:
#                                   points
# variety
# Grüner Veltliner               86.258065
# Nebbiolo                       86.173913
# Corvina, Rondinella, Molinara  86.040816
# Barbera                        85.737705
# Bordeaux-style White Blend     85.720000

# %% [markdown]
# Получили ТОП-5 средних оценок вин из бюджетных сортов винограда, в тройку вошли Grüner Veltliner, Nebbiolo, Corvina, Rondinella, Molinara

# %% [markdown]
# price

# %%
df["price"].describe()
# Out:
# count    13387.000000
# mean        34.803093
# std         42.991402
# min          5.000000
# 25%         16.000000
# 50%         25.000000
# 75%         41.000000
# max       2300.000000
# Name: price, dtype: float64

# %% [markdown]
# Для каждой страны найдем среднюю, максимальную, минимальную цену вина. Для каждой страны найдём количество записей

# %% [markdown]
# ТОП 10 стран с самой высокой средней ценой вина

# %%
data_to_plot = df.groupby(['country',]).mean()['price'].sort_values(ascending=False).to_frame()
data_to_plot.head(10)
# Out:
#                 price
# country
# Turkey      55.333333
# France      50.450770
# Italy       42.803704
# Canada      39.588235
# Germany     36.831579
# Luxembourg  36.000000
# Austria     34.416667
# US          34.173657
# Lebanon     33.333333
# Australia   31.620172

# %%
df_plot = df.groupby(['country',]).mean()['price'].sort_values(ascending=False).plot(kind='pie', figsize=(15,15))
plt.title("Средняя цена вина по каждой стране",fontsize=15)
plt.xlabel('Рисунок 6. - Распределение средней цены по странам',fontsize=15)
plt.ylabel('country',fontsize=20);

# %% [markdown]
# Видно что первые 3 строчки рейтинга с максимальной средней стоимостью вина занимают страны Европейского континента. Самая высокая средняя цена в Турции, Франции и Италии. Далее идет Канада

# %%
country_price = df.groupby(['country',]).mean()['price'].sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_price.price ,y = country_price.index, color='maroon', orient='h')
plt.title('Средняя цена по стране',fontsize=15)
plt.xlabel('price',fontsize=15);
plt.ylabel('country',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 7. - Зависимость средней цены от страны", fontsize=15 );

# %% [markdown]
# Самая высокая средняя цена вина в Турции, самая низкая в Болгарии.

# %% [markdown]
# ТОП 10 стран с самым высоким средним рейтингом вина

# %%
country_points = df.groupby(['country',]).mean()['points'].sort_values(ascending=False).to_frame()
country_points.head(10)
# Out:
#               points
# country
# Austria    89.254630
# Germany    88.968421
# France     88.748158
# Italy      88.709630
# Slovenia   88.500000
# Portugal   88.325056
# Australia  88.038627
# Turkey     88.000000
# Cyprus     88.000000
# US         87.900724

# %% [markdown]
# В первой пятёрке рейтинга: Austria, Germany, France, Italy и Slovenia

# %%
df["points"].mean() #Средний рейтинг по странам
# Out:
# 87.88907148726376

# %%
country_points = df.groupby(['country',]).mean()['points'].sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_points.points ,y = country_points.index, color='maroon', orient='h')
plt.title('Средний рейтинга по стране',fontsize=15)
plt.xlabel('Points',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 8. - Зависимость рейтинг от страны", fontsize=15 );
plt.ylabel('country',fontsize=15);

# %%
# Характеристики рейтинга по континентам среднее значение (mean), 
# медианное значение (median),дисперсию (variance), стандартное отклонение (standard deviation)
country= df.groupby('country_to_continent').agg({'points': ['mean','median', 'var','std','sem']})
country['Counts'] =df['country_to_continent'].value_counts()
# Покажем страны которые упоминаются более 1000 раз
country_1000 = country[country['Counts']>1000]
country_1000
# Out:
#                          points                                       Counts
#                            mean median        var       std       sem
# country_to_continent
# Europe                88.367793   88.0   9.641450  3.105068  0.046599   4440
# Latin America         86.235489   86.0   8.762756  2.960195  0.085241   1206
# North America         87.899925   88.0  11.908858  3.450921  0.042334   6645

# %% [markdown]
# Наиболее распространенными встроенными функциями агрегирования являются базовые математические функции, включая сумму (sum), среднее значение (mean), медианное значение (median), минимум (minimum), максимум (maximum), стандартное отклонение (standard deviation), дисперсию (variance), среднее абсолютное отклонение (mean absolute deviation) и произведение (product).

# %%
#Характеристики цены по странам среднее значение (mean), медианное значение (median),дисперсию (variance), стандартное отклонение (standard deviation) 
country= df.groupby('country').agg({'price': ['mean','median', 'var','std','sem']})
country['Counts'] =df['country'].value_counts()
# Покажем страны которые упоминаются более 1000 раз
country_1000 = country[country['Counts']>1000]
country_1000
# Out:
#              price                                          Counts
#               mean median          var        std       sem
# country
# France   50.450770   30.0  8572.161951  92.585971  2.396157   1493
# Italy    42.803704   30.0  2035.647874  45.118155  1.227961   1350
# US       34.173657   28.0   562.387071  23.714702  0.291291   6628

# %%
# Марки вин с самым высоким рейтингом
country_points = df.groupby(['variety',]).max()['points'].sort_values(ascending=False).to_frame()
country_points.head(10)
# Out:
#                           points
# variety
# Merlot                       100
# Chardonnay                   100
# Portuguese Red                99
# Bordeaux-style Red Blend      99
# Nebbiolo                      99
# Cabernet Sauvignon            98
# Pinot Noir                    98
# Sangiovese                    98
# Sparkling Blend               98
# Malbec                        97

# %%
# Провинции с самым высоким рейтингом
country_points = df.groupby(['province',]).max()['points'].sort_values(ascending=False).to_frame()
country_points.head(10)
# Out:
#                   points
# province
# Tuscany              100
# Champagne            100
# Piedmont              99
# Douro                 99
# Bordeaux              99
# Burgundy              98
# California            98
# South Australia       97
# Mendoza Province      97
# Washington            97

# %% [markdown]
# Для каждой страны найдем максимальную цену вина

# %%
df.nlargest(5,'price') # Выведем 5 самых дорогих вин в мире
# Out:
#        country                                        description  \
# 13188   France  A big, powerful wine that sums up the richness...
# 323     France  A wine that has created its own universe. It h...
# 4324   Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 19501   France  While there is certainly plenty of wood here, ...
# 19147   France  From arguably the finest white wine vineyard i...
#
#                    designation  points   price   province       region_1  \
# 13188                      NaN      99  2300.0   Bordeaux       Pauillac
# 323             Clos du Mesnil     100  1400.0  Champagne      Champagne
# 4324   Ried Loibenberg Smaragd      94  1100.0     Wachau            NaN
# 19501                      NaN      95   850.0   Bordeaux  Saint-Émilion
# 19147                      NaN      98   757.0   Burgundy     Montrachet
#
#                         variety                winery  color  \
# 13188  Bordeaux-style Red Blend        Château Latour    red
# ...

# %%
# Для каждой страны найдем максимальную цену вина. Выведем ТОП 5 стран.
max_price = df.groupby(['country',]).max()['price'].sort_values(ascending=False).to_frame()
max_price.head(5)
# Out:
#             price
# country
# France     2300.0
# Austria    1100.0
# Spain       599.0
# Australia   550.0
# Italy       495.0

# %%
max_price = df.groupby(['country',]).max()['price'].sort_values(ascending=False).to_frame()
max_price.tail(5)
# Out:
#              price
# country
# Bulgaria      20.0
# Switzerland   19.0
# Cyprus        17.0
# Georgia       14.0
# Ukraine       13.0

# %%
plt.figure(figsize=(10,10))
sns.pointplot(x = max_price.price ,y = max_price.index, color='maroon', orient='h')
plt.title('Максимальная цена по стране',fontsize=20)
plt.xlabel('price',fontsize=15);
plt.ylabel('country',fontsize=15)
plt.figtext(0.2,0 , "Рисунок 9. - Зависимость страны от максимальной цены", fontsize=15 );

# %%
min_price = df.groupby(['country',]).min()['price'].sort_values(ascending=False).to_frame()
min_price.tail()
# Out:
#            price
# country
# Chile        6.0
# Italy        6.0
# Spain        5.0
# Portugal     5.0
# Australia    5.0

# %%
plt.figure(figsize=(10,10))
sns.pointplot(x = min_price.price ,y = min_price.index, color='maroon', orient='h')
plt.title('Минимальная цена по стране',fontsize=15)
plt.xlabel('country',fontsize=15);
plt.ylabel('country',fontsize=15)
plt.figtext(0.1,0 , "Рисунок 10. - Зависимость страны от минимимальной цены", fontsize=15);

# %% [markdown]
# Самая низкая цена вина в Australia, стоимость бутылки 5 долларов США. Самая высокая во Франции - 2300 долларов США.

# %% [markdown]
# Различные рейтинги вин

# %%
# Определим средний рейтинг в наборе данных
meand_points = df["points"].mean()
meand_points
# Out:
# 87.88907148726376

# %%
df["points"].max() # Определим максимальный рейтинг в наборе данных
# Out:
# 100

# %%
pp = df[['variety', 'points']].copy() # выведем сорта с максимальным значением рейтинга
pp[pp.points == pp.points.max()]
# Out:
#          variety  points
# 323   Chardonnay     100
# 5955      Merlot     100

# %% [markdown]
# Рейтинги у сортов Chardonnay и Merlot самые высокие

# %% [markdown]
# Построим график «ящик с усами» по рейтингам от сорта винограда

# %%
fig = plt.figure(figsize=(20,10))
variety_points = df.variety.value_counts().head(10)
variety_points_wines = df[df.variety.isin(variety_points.index)]
x = variety_points_wines.variety
y = variety_points_wines.points
sns.boxplot(x,y)
plt.xlabel('Сорт винограда', fontsize=20)
plt.ylabel('Рейтинг', fontsize=20)
plt.title('Распределения рейтинга вина по топ 10 сортов винограда',fontsize=20)
plt.figtext(0.2, 0, "Рисунок 11. - Зависимость рейтинга от топ 10 популярных сортов винограда",fontsize=20);

# %% [markdown]
# Визуально видно, что рейтинги высокие у сортов Bordeaux-style Red Blend и Pinot Noir

# %%
top_country_wines = df.country.value_counts().head(10)
top_country_wines
# Out:
# US             6628
# France         1493
# Italy          1350
# Chile           654
# Spain           541
# Argentina       536
# Australia       466
# Portugal        443
# New Zealand     346
# Germany         285
# Name: country, dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
points_top_country_wines = df[df.country.isin(top_country_wines.index)]
x = points_top_country_wines.country
y = points_top_country_wines.points
sns.boxplot(x,y)
plt.xlabel('сountry', fontsize=20)
plt.ylabel('Points', fontsize=20)
plt.title('Распределение баллов в топ-10 перечисленных стран',fontsize=20)
plt.figtext(0.3, 0, "Рисунок 12. ТОП 10 стран по рейтингу вина",fontsize=20 );

# %% [markdown]
# На сюжете показано распределение точек топ-10 сортов вин, имеющих максимальное количество отзывов. В лидерах Германия, Франция, Италия

# %%
# Страны с самым высоким median рейтингом(ТОП 10)
country_points = df.groupby('country').median()['points'].sort_values(ascending=False).to_frame()
country_points_10 = country_points.head(10)
country_points_10
# Out:
#            points
# country
# Austria      89.0
# Turkey       89.0
# Germany      89.0
# Slovenia     88.5
# Italy        88.0
# France       88.0
# Australia    88.0
# Israel       88.0
# Cyprus       88.0
# Canada       88.0

# %% [markdown]
# Максимальные значения медианы оценки качества вина получили европейские страны Austria, Turkey и Germany

# %%
country_points = country_points_10.groupby('country').median()['points'].sort_values(ascending=False).plot(kind='pie', figsize=(15,15))
plt.title("Медиана оценки качества по каждой стране (ТОП 10)",fontsize=15)
plt.xlabel('Рисунок 13. - Медиана оценки качества по странам',fontsize=15)
plt.ylabel('country',fontsize=20);

# %%
# выведем сорта с рейтингом ниже среднего которые чаще всего упоминаются в датафрейме
pp = df[['variety', 'points']].copy() 
pp[pp.points <= meand_points].value_counts().head(10)
# Out:
# variety             points
# Chardonnay          87        238
# Pinot Noir          87        197
# Cabernet Sauvignon  87        169
# Chardonnay          86        162
# Pinot Noir          86        152
# Chardonnay          84        139
# Red Blend           87        135
# Chardonnay          85        125
# Cabernet Sauvignon  86        125
# Sauvignon Blanc     87        121
# dtype: int64

# %% [markdown]
# Выявим закономерность влияния на цену цвета и рейтинга. Построим диаграмму рассеивания и посчитаем корреляцию

# %%
def goodRating(row): # Создадим столбец 'good' из 0, 1, 2 в соответствии с цветом вина
    if row['color'] == 'red':
        val = 0
    elif row['color'] == 'white':
        val = 1
    else:
        val = 2
    return(val)
df['good'] = df.apply(goodRating, axis=1)

# %%
df.groupby('color').mean()['points']
# Out:
# color
# other    87.323838
# red      88.046395
# white    87.632705
# Name: points, dtype: float64

# %% [markdown]
# Построим диаграмму рассеивания и посчитаем корреляцию

# %%
fig = plt.figure(figsize=(20,15))
xx = np.log(df.price)
yy = df.points
plt.scatter(xx,yy)
plt.xlabel('log(price)', fontsize=20)
plt.ylabel('Points', fontsize=20)
plt.title('Корреляция между points и price',fontsize=20)
plt.figtext(0.3, 0, "Рисунок 14. - График корреляция между points и price",fontsize=20);

# %% [markdown]
# Определение корреляции между переменными с помощью коэффициента корреляции Пирсона

# %%
df.corr(method='pearson')
# Out:
#           points     price     GoodR      good
# points  1.000000  0.418949  0.811861 -0.068789
# price   0.418949  1.000000  0.283426 -0.102787
# GoodR   0.811861  0.283426  1.000000 -0.066698
# good   -0.068789 -0.102787 -0.066698  1.000000

# %% [markdown]
# Большая зависимость наблюдается между price и points

# %% [markdown]
# Построение тепловой карты для коррелированных атрибутов

# %%
corrValues = df.corr(method='pearson')
topCorrFeaturesForEarnig = corrValues.index[abs(corrValues['price']) >= 0.1]
print(topCorrFeaturesForEarnig)
plt.figure(figsize=(6,6))
plt.xlabel('log(price)', fontsize=20)
plt.ylabel('Points', fontsize=20)
plt.title('Корреляция между points и price и good',fontsize=15)
plt.figtext(0.1, 0, "Рисунок 15. - График корреляция между points и price и good",fontsize=20)
ax = sns.heatmap(df[topCorrFeaturesForEarnig].corr(), annot=True, cmap="RdYlGn");
# Out:
# Index(['points', 'price', 'GoodR', 'good'], dtype='object')

# %% [markdown]
# Для статистиков и исследователей данных проверка статистической гипотезы представляет собой формальную процедуру. Стандартный подход к проверке статистической гипотезы подразумевает определение области исследования, принятие решения в отношении того, какие переменные необходимы для измерения предмета изучения, и затем выдвижение двух конкурирующих гипотез. Во избежание рассмотрения только тех данных, которые подтверждают наши субъективные оценки, исследователи четко констатируют свою гипотезу заранее. Затем, основываясь на данных, они применяют выборочные статистики с целью подтвердить либо отклонить эту гипотезу.

# %% [markdown]
# Выясним как распределена цена

# %%
import scipy.stats as stat

# %%
value, p = stat.normaltest(df['price'].sample(50))
print(value, p)
if p >= 0.05:
    print('Цена распределена нормально')
else:
    print('Маловероятно, что цена распределена нормально')
# Out:
# 34.23603458470839 3.679082688203709e-08
# Маловероятно, что цена распределена нормально

# %% [markdown]
# Видно, что р практически равно 0, ответ Маловероятно, что цена распределена нормально

# %%
from scipy.stats.stats import pearsonr
y = pearsonr(df["price"], df["points"])
y
# Out:
# (0.4189486536141557, 0.0)

# %% [markdown]
# Коэффициент корреляции Пирсона измеряет линейную зависимость между двумя наборами данных.

# %%
value, p = stat.normaltest(df['price'].sample(50))
print(value, p)
if p >= 0.05:
    print('Цена распределяется нормально от качества вина')
else:
    print('Маловероятно, что цена распределяется нормально от качества вина')
# Out:
# 89.32038175197155 4.020921012171394e-20
# Маловероятно, что цена распределяется нормально от качества вина

# %% [markdown]
# Тест проверяет отличается ли образец от нормального распределения.

# %% [markdown]
# Эта функция проверяет нулевую гипотезу о том, что образец происходит из нормального распределения.

# %%
from scipy.stats.stats import pearsonr
y = pearsonr(df["price"], df["good"]) 
y
# Out:
# (-0.10278686446894754, 8.965731629487849e-33)

# %%
value, p = stat.normaltest(df['price'].sample(50))
print(value, p)
if p >= 0.05:
    print('цена распределяется нормально от цвета вина')
else:
    print('Маловероятно, что цена распределяется нормально от цвета вина')
# Out:
# 92.82250442070057 6.979901064438929e-21
# Маловероятно, что цена распределяется нормально от цвета вина

# %%
plt.subplots(figsize=(5,3), dpi=160)
colors = {0:'purple', 1:'orange',2:'green'}
plt.scatter(df.price, df.points, alpha=0.6, c=df.good.apply(lambda x: colors[x]))
plt.xlim(0,700)
plt.title('Зависимость цены и качества от цвета вина',fontsize=10)
plt.figtext(0, -0.1, "Рисунок 16. Диаграмма рассеяния между points и price по цвету вина",fontsize=10)
plt.xlabel('price', fontsize=10)
plt.ylabel('Points', fontsize=10);

# %% [markdown]
# Видно, что есть определённая зависимость между рейтингом и ценой. При увеличении цены увеличивается рейтинг. Но это происходит не всегда. рейтинг не влияет на цене. Цена вина с высоким рейтингом равна цене с низким H1: В средним рейтинг влияет на цену. Цена вина с высоким рейтингом больше цены с низким

# %% [markdown]
# #  <a name="3">3. Портрет пользователя</a>

# %% [markdown]
# Определить для пользователя каждого континента :
#
# Самые популярные сорта (топ-5). Влияет ли рейтинг на цены по регионам?

# %% [markdown]
# Определим самый популярный сорт вина по каждой стране

# %%
dd = df.groupby('country').variety.apply(lambda x:x.value_counts().nlargest(1)).to_frame()
dd.head()
# Out:
#                             variety
# country
# Argentina Malbec                246
# Australia Shiraz                164
# Austria   Grüner Veltliner      111
# Brazil    Sparkling Blend         2
# Bulgaria  Chardonnay              2

# %% [markdown]
# Отсортируем по максимальном значениям количества упоминаний. Получим самый популярный сорт вина на континенте(ТОП 5)

# %%
sorted_dd = dd.sort_values(by='variety', ascending=False).head() 
sorted_dd.head()
# Out:
#                      variety
# country
# US      Pinot Noir      1241
# Italy   Red Blend        351
# France  Chardonnay       272
# Germany Riesling         272
# Spain   Tempranillo      249

# %%
a = df[df.price <= 150][df.points <100]
# Out:
# C:\Users\majes\AppData\Local\Temp\ipykernel_10188\1653860119.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = df[df.price <= 150][df.points <100]

# %%
df.groupby(['variety','country','points'])['points'].agg('count').sort_values(ascending=False).head()
# Out:
# variety     country  points
# Pinot Noir  US       87        150
# Chardonnay  US       87        141
# Pinot Noir  US       90        134
#                      88        126
#                      92        123
# Name: points, dtype: int64

# %%
df.groupby(['variety','color'])['price'].agg('count').sort_values(ascending=False).to_frame().head()
# Out:
#                           price
# variety            color
# Pinot Noir         red     1660
# Chardonnay         white   1588
# Cabernet Sauvignon red     1462
# Red Blend          red     1084
# Sauvignon Blanc    white    729

# %% [markdown]
# В производстве самые популярные вина Pinot Noir и Chardonnay

# %%
df.groupby(['color'])['price'].agg('count').sort_values(ascending=False).to_frame().head(10)
# Out:
#        price
# color
# red     8794
# white   3926
# other    667

# %%
df[df['points'] == 100]
# Out:
#      country                                        description  \
# 323   France  A wine that has created its own universe. It h...
# 5955   Italy  A perfect wine from a classic vintage, the 200...
#
#          designation  points   price   province   region_1     variety  \
# 323   Clos du Mesnil     100  1400.0  Champagne  Champagne  Chardonnay
# 5955         Masseto     100   460.0    Tuscany    Toscana      Merlot
#
#                      winery  color country_to_continent  GoodR  good
# 323                    Krug  white               Europe      1     1
# 5955  Tenuta dell'Ornellaia    red               Europe      1     0

# %%
dd = df[df['points'] == 100]
dd = list(dd['variety'])

# %%
print("Вина получившие максимальную оценку в мире", dd[0], 'и', dd[1])
# Out:
# Вина получившие максимальную оценку в мире Chardonnay и Merlot

# %%
dd = df[df['points'] == 80]
dd = list(dd['variety'])
print("Вина получившие минимальную оценку в мире", dd[0], 'и', dd[1])
# Out:
# Вина получившие минимальную оценку в мире Pinot Noir и Sauvignon Blanc

# %% [markdown]
# Построим гистограмму для самых популярных вин по каждой стране ТОП-5

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.xlabel("Страна, марка вина",fontsize=20)
plt.ylabel("Количество упоминаний",fontsize=20)
plt.title("Количество вина для страны ТОП-5",fontsize=20)
sorted_dd.plot(ax=ax, kind='bar')
plt.figtext(0.3, -0.2, "Рисунок 17. - Гистограмма самых популярных вин по каждой стране ТОП-5",fontsize=20)
plt.xlabel("Страна, марка вина",fontsize=20)
plt.ylabel("Количество упоминаний",fontsize=20)
plt.show()

# %% [markdown]
# Определим самые популярные вина по каждму континенту ТОП-5

# %%
dd = df.groupby('country_to_continent').variety.apply(lambda x:x.value_counts().nlargest(1))
dd.head(6)
# Out:
# country_to_continent
# Africa                Sauvignon Blanc         41
# Asia                  Cabernet Sauvignon      19
# Europe                Red Blend              548
# Latin America         Malbec                 263
# North America         Pinot Noir            1244
# Oceania               Shiraz                 164
# Name: variety, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.xlabel("Страна, марка вина",fontsize=20)
plt.ylabel("Количество упоминаний",fontsize=20)
plt.title("Количество вина для каждого рейтинга",fontsize=20)
sorted_dd.plot(ax=ax, kind='bar')
plt.figtext(0.3, -0.2, "Рисунок 18. - Гистограмма самых популярных вин на континенте",fontsize=20)
plt.xlabel("Страна, марка вина",fontsize=20)
plt.ylabel("Количество упоминаний",fontsize=20)
plt.show()

# %%
s = df['country_to_continent'].unique()
s
# Out:
# array(['North America', 'Europe', 'Latin America', 'Oceania', 'Africa',
#        'Asia'], dtype=object)

# %%
s[1]
# Out:
# 'Europe'

# %% [markdown]
# По каждому континенту определим процентное соотношение самых популярных марок вина

# %%
dd = df.groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd
# Out:
#                                           variety
# country_to_continent variety
# Africa               Sauvignon Blanc     0.193396
#                      Chardonnay          0.183962
#                      Shiraz              0.160377
#                      Cabernet Sauvignon  0.117925
#                      Red Blend           0.084906
# ...                                           ...
# Oceania              Champagne Blend     0.004926
#                      Rosé                0.002463
#                      Zinfandel           0.002463
#                      Malbec              0.001232
#                      Tempranillo         0.001232
#
# [131 rows x 1 columns]

# %%
for i in range(len(s)):
    print(i, s[i])
# Out:
# 0 North America
# 1 Europe
# 2 Latin America
# 3 Oceania
# 4 Africa
# 5 Asia

# %% [markdown]
# ТОП 5 вин для North America

# %%
dd=df.loc[(df['country_to_continent'] == 'North America')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                           variety
# country_to_continent variety
# North America        Pinot Noir          0.187208
#                      Cabernet Sauvignon  0.158766
#                      Chardonnay          0.140256
#                      Syrah               0.070579
#                      Zinfandel           0.069074

# %% [markdown]
# ТОП 5 вин для Europe

# %%
dd=df.loc[(df['country_to_continent'] == 'Europe')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                                 variety
# country_to_continent variety
# Europe               Red Blend                 0.123423
#                      Riesling                  0.086937
#                      Chardonnay                0.079279
#                      Sangiovese                0.062838
#                      Bordeaux-style Red Blend  0.056532

# %% [markdown]
# ТОП 5 вин для Latin America

# %%
dd=df.loc[(df['country_to_continent'] == 'Latin America')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                           variety
# country_to_continent variety
# Latin America        Malbec              0.218076
#                      Cabernet Sauvignon  0.204809
#                      Chardonnay          0.102819
#                      Red Blend           0.087894
#                      Sauvignon Blanc     0.087894

# %% [markdown]
# ТОП 5 вин для Africa

# %%
dd=df.loc[(df['country_to_continent'] == 'Africa')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                           variety
# country_to_continent variety
# Africa               Sauvignon Blanc     0.193396
#                      Chardonnay          0.183962
#                      Shiraz              0.160377
#                      Cabernet Sauvignon  0.117925
#                      Red Blend           0.084906

# %% [markdown]
# ТОП 5 вин для Oceania

# %%
dd=df.loc[(df['country_to_continent'] == 'Oceania')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                           variety
# country_to_continent variety
# Oceania              Shiraz              0.201970
#                      Sauvignon Blanc     0.166256
#                      Chardonnay          0.158867
#                      Pinot Noir          0.146552
#                      Cabernet Sauvignon  0.084975

# %% [markdown]
# ТОП 5 вин для Asia

# %%
dd=df.loc[(df['country_to_continent'] == 'Asia')].groupby(['country_to_continent'])['variety'].value_counts(normalize=True).to_frame()
dd.head()
# Out:
#                                                 variety
# country_to_continent variety
# Asia                 Cabernet Sauvignon        0.263889
#                      Chardonnay                0.166667
#                      Red Blend                 0.125000
#                      Bordeaux-style Red Blend  0.083333
#                      Merlot                    0.069444

# %%
continent= df.groupby('country_to_continent').agg({'points': ['mean','median','max', 'var', 'std','sem']})
#добавление столбцов по количеству отзывов
continent['Counts']=df['country_to_continent'].value_counts()
#creating dataframe
continent_plot = pd.DataFrame(continent).reset_index()
continent_plot = continent_plot.sort_values(("points","mean"), ascending=False)
continent_plot
# Out:
#   country_to_continent     points                                             \
#                              mean median  max        var       std       sem
# 2               Europe  88.367793   88.0  100   9.641450  3.105068  0.046599
# 4        North America  87.899925   88.0   98  11.908858  3.450921  0.042334
# 5              Oceania  87.884236   88.0   97   7.500762  2.738752  0.096111
# 1                 Asia  87.250000   87.5   92   6.415493  2.532882  0.298503
# 0               Africa  87.165094   87.0   92   5.711951  2.389969  0.164144
# 3        Latin America  86.235489   86.0   97   8.762756  2.960195  0.085241
#
#   Counts
#
# 2   4440
# 4   6645
# 5    812
# 1     72
# 0    212
# 3   1206

# %% [markdown]
# Доля каждого вина в стране

# %%
data_grp1 = df.groupby(['country'])['color'].value_counts(normalize=True).to_frame()
data_grp1
# Out:
#                     color
# country   color
# Argentina red    0.852612
#           white  0.132463
#           other  0.014925
# Australia red    0.658798
#           white  0.311159
# ...                   ...
# US        white  0.268709
#           other  0.025649
# Ukraine   other  1.000000
# Uruguay   red    0.800000
#           white  0.200000
#
# [74 rows x 1 columns]

# %%
data_grp1.plot(kind='bar', stacked=True, figsize=(15, 10))
plt.title("Процентное соотношение доли каждого вина в стране",fontsize=20)
plt.figtext(0.3, -0.2, "Рисунок 19. - Доля каждого вина в стране",fontsize=20)
plt.xlabel("Страна, цвет вина",fontsize=20)
plt.ylabel("Доля вина",fontsize=20)
plt.show()

# %% [markdown]
# ТОП-5 стран производителей красного вина

# %%
dd = df [df [ 'color' ] == 'red' ].groupby(['color'])['country'].value_counts(normalize=True)
dd.head()
# Out:
# color  country
# red    US           0.531840
#        Italy        0.126905
#        France       0.076188
#        Chile        0.052081
#        Argentina    0.051967
# Name: country, dtype: float64

# %% [markdown]
# ТОП-5 стран производителей белого вина

# %%
dd = df [df [ 'color' ] == 'white' ].groupby(['color'])['country'].value_counts(normalize=True)
dd.head()
# Out:
# color  country
# white  US             0.453642
#        France         0.139582
#        Germany        0.070555
#        New Zealand    0.056801
#        Austria        0.048141
# Name: country, dtype: float64

# %% [markdown]
# Как различается средняя цена по континентам. Построим график средней цены по континентам

# %%
country_to_continent = df.groupby(['country_to_continent',]).mean()['price'].sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_to_continent.price,y = country_to_continent.index, color='maroon', orient='h')
plt.title('Средняя цена по континентам',fontsize=15)
plt.xlabel('price',fontsize=15);
plt.ylabel('continent',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 20. - Зависимость средней цены от континента", fontsize=15 );

# %% [markdown]
# Самая низкая средняя цена в Латинской Америке, самая высокая В Европе

# %% [markdown]
# Как различается средний рейтинг по континентам. Построим график средней цены по континентам

# %%
country_to_continent = df.groupby(['country_to_continent',]).mean()['points'].sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_to_continent.points ,y = country_to_continent.index, color='maroon', orient='h')
plt.title('Средний рейтинг по континентам',fontsize=15)
plt.xlabel('points',fontsize=15);
plt.ylabel('continent',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 21. - Зависимость среднего рейтинга от континента", fontsize=15);

# %% [markdown]
# Из двух рисунков видно, что в Латинской Америке самые низкие средние цены и рейтинги, в Европе самые высокие. Скорее всего это связано с требованиями по качеству вина в данных континентах и с уровнем жизни.Так же спрос формирует цену. Цена будет расти, пока за продукт готовы ее платить. Вот почему «топовые» винтажи могут стоить от 2300 $ за бутылку. в Америке и Европе самые высокие средние рейтинги и цены, в Латинской Америке и Африке самые низкие.

# %%
fig = plt.figure(figsize=(10,5))
plt.title('Распределение цены к рейтингу',fontsize=15)
a = df[df.price <= 150][df.points <100]
plt.figtext(0.3, 0, "Рисунок 22. Зависимость рейтинга от цены",fontsize=15 );
sns.boxplot(x = 'points', y = 'price', data = a);
# Out:
# C:\Users\majes\AppData\Local\Temp\ipykernel_10188\630238542.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = df[df.price <= 150][df.points <100]

# %% [markdown]
# Выяснили, что есть зависимость среднего рейтинга от средней цены. При увеличении рейтинга растет и цена. В Латинской Америке самые низкие средние цены и рейтинги, в Европе самые высокие

# %% [markdown]
# #  <a name="4"> 4. Исследование статистических показателей.</a>

# %% [markdown]
# Выполнить подсчитать среднего количества, дисперсии и стандартного отклонения для цен на продукт различных регионов. Построить гистограммы. Описать распределения. Построить линейную регрессию зависимости между ценой продукта и его рейтингом.

# %% [markdown]
# Подсчитаем среднее количество, дисперсии и стандартного отклонения для цен на продукт различных регионов

# %%
continent= df.groupby('country_to_continent').agg({'points': ['mean','median', 'var','std','sem']})
#adding columns on numbers of reviews
continent['Counts'] =df['country_to_continent'].value_counts()
#creating dataframe
continent_plot = pd.DataFrame(continent).reset_index()
continent_plot = continent_plot.sort_values(("points","mean"), ascending=False)
continent_plot
# Out:
#   country_to_continent     points                                       Counts
#                              mean median        var       std       sem
# 2               Europe  88.367793   88.0   9.641450  3.105068  0.046599   4440
# 4        North America  87.899925   88.0  11.908858  3.450921  0.042334   6645
# 5              Oceania  87.884236   88.0   7.500762  2.738752  0.096111    812
# 1                 Asia  87.250000   87.5   6.415493  2.532882  0.298503     72
# 0               Africa  87.165094   87.0   5.711951  2.389969  0.164144    212
# 3        Latin America  86.235489   86.0   8.762756  2.960195  0.085241   1206

# %%
continent_plot.mean()
# Out:
# points  mean        87.467090
#         median      87.416667
#         var          8.323545
#         std          2.862965
#         sem          0.122155
# Counts            2231.166667
# dtype: float64

# %% [markdown]
# mean - среднее значение, median - медиана, var - дисперсия, std — стандартное отклонение значения. min — минимальное значение. max — максимальное значение,sem - показатель стандартной погрешности среднего значения входных данных. В статистике дисперсия - это мера того, насколько отдельные (числовые) значения в наборе данных отличаются от среднего значения . Дисперсия часто используется для количественной оценки разброса или дисперсии. Распространение - это характеристика выборки или генеральной совокупности, которая описывает степень ее изменчивости.
#
# Высокая дисперсия говорит нам о том, что значения в нашем наборе данных далеки от своего среднего. Таким образом, наши данные будут иметь высокий уровень изменчивости. С другой стороны, низкая дисперсия говорит нам о том, что значения довольно близки к среднему. В этом случае данные будут иметь низкий уровень изменчивости.

# %%
country_to_continent = df.groupby(['country_to_continent',]).mean()['points'].sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_to_continent.points ,y = country_to_continent.index, color='maroon', orient='h')
plt.title('Средний рейтинг по континентам',fontsize=15)
plt.xlabel('points',fontsize=15);
plt.ylabel('continent',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 21. - Зависимость среднего рейтинга от континента", fontsize=15);

# %% [markdown]
# Чтобы вычислить дисперсию в наборе данных, нам сначала нужно найти разницу между каждым отдельным значением и средним значением. Проверим данные с помощью формул

# %% [markdown]
# Вычислим с помощью формулы среднее значение points и дисперсию

# %%
data = df['points']
list(data)[0 :6]
# Out:
# [86, 96, 91, 81, 83, 96]

# %%
n = len(data)
n
# Out:
# 13387

# %%
sum(data)
# Out:
# 1176571

# %%
mean = sum(data) / n
mean
# Out:
# 87.88907148726376

# %%
df["points"].mean()
# Out:
# 87.88907148726376

# %%
deviations = [(x - mean) ** 2 for x in (data)]
variance = sum(deviations) / n
print('Дисперсия =', variance)
# Out:
# Дисперсия = 10.807520068616897

# %% [markdown]
# С другой стороны, мы можем использовать Python variance() для вычисления дисперсии выборки и использовать ее для оценки дисперсии всей генеральной совокупности.

# %%
import statistics
statistics.pvariance(data)
# Out:
# 10.807520068617816

# %% [markdown]
# мы работаем с выборкой и хотим оценить дисперсию генеральной совокупности, то нам нужно обновить выражение variance = sum(deviations) / n до variance = sum(deviations) / (n - 1)

# %%
deviations = [(x - mean) ** 2 for x in (data)]
variance = sum(deviations) / n-1
print('дисперсию генеральной совокупности =', variance)
# Out:
# дисперсию генеральной совокупности = 9.807520068616897

# %% [markdown]
# Посмотрим на распределение оценки качества вина по количеству упоминаний

# %%
df['points'].value_counts().sort_index().plot.area(figsize=(8,4))
plt.title('Распределение оценки качества вина по количеству упоминаний',fontsize=15)
plt.xlabel('points',fontsize=10);
plt.ylabel('количество',fontsize=10);
plt.figtext(0.1, -0.1, "Рисунок 24. - Зависимость среднего рейтинга от континента",fontsize=20);

# %% [markdown]
# Видно, что оценки распределены в основном в диапазоне от 85 до 92, основное количество вин оценены в этом диапазоне

# %%
continent= df.groupby('country_to_continent').agg({'points': ['mean','median', 'var','std','sem']})
#adding columns on numbers of reviews
continent['Counts'] =df['country_to_continent'].value_counts()
#creating dataframe
continent_plot = pd.DataFrame(continent).reset_index()
continent_plot = continent_plot.sort_values(("points","mean"), ascending=False)
continent_plot
# Out:
#   country_to_continent     points                                       Counts
#                              mean median        var       std       sem
# 2               Europe  88.367793   88.0   9.641450  3.105068  0.046599   4440
# 4        North America  87.899925   88.0  11.908858  3.450921  0.042334   6645
# 5              Oceania  87.884236   88.0   7.500762  2.738752  0.096111    812
# 1                 Asia  87.250000   87.5   6.415493  2.532882  0.298503     72
# 0               Africa  87.165094   87.0   5.711951  2.389969  0.164144    212
# 3        Latin America  86.235489   86.0   8.762756  2.960195  0.085241   1206

# %%
plt.scatter(continent_plot['country_to_continent'],continent_plot[('points','mean')], c=continent['Counts'], cmap=cm.rainbow)
plt.xticks(rotation = 45)
plt.xlabel("country_to_continent")
plt.ylabel("Рейтинг средний")
plt.title("Континент")
plt.ylim(86,89)
plt.grid(alpha = 0.5)
plt.colorbar(cmap=cm.rainbow, orientation='vertical', label = "Color by # of Reviews")
plt.figtext(0.1, -0.2 , "Рисунок 25. - Зависимость рейтига от континента" );

# %% [markdown]
# Вычислим с помощью формулы среднее значение price и дисперсию

# %% [markdown]
# Максимальная цена за бутылку составляет

# %%
max_price =df [ 'price' ]. max ()
max_price
# Out:
# 2300.0

# %% [markdown]
# Средняя цена за бутылку составляет

# %%
avg_cost = df["price"].mean()
avg_cost
# Out:
# 34.803092552476286

# %% [markdown]
# Покажем на графике распределение цены

# %%
df['price'].value_counts().sort_index().plot(figsize=(15,8))
plt.title('Распределение цены вина по количеству упоминаний',fontsize=23)
plt.xlabel('цена',fontsize=10);
plt.ylabel('количество',fontsize=10);
plt.xlim(0,300)
plt.figtext(0.3, -0.1, "Рисунок 26. - Распределение цены вина",fontsize=23 );

# %% [markdown]
# Покажем на графике среднюю стоимость вина на континентах

# %%
top_5 = df.groupby('country_to_continent').mean().sort_values(by = ['price'], ascending = False)
top_5 = pd.DataFrame(top_5.iloc[0:5,1])
top_5['Index'] = list(range(5))
top_5['Country'] = top_5.index.values
top_5.set_index(['Index'],inplace = True)
top_5
# Out:
#            price        Country
# Index
# 0      41.125000         Europe
# 1      34.187509  North America
# 2      31.541667           Asia
# 3      28.614532        Oceania
# 4      22.264151         Africa

# %%
continent_plot = df.groupby(['country_to_continent',]).mean()['price'].sort_values(ascending = False)
plt.figure(figsize=(10,10))
sns.pointplot(x = country_to_continent.points ,y = country_to_continent.index, color='maroon', orient='h')
plt.title('Средняя цена по континентам',fontsize=15)
plt.xlabel('price',fontsize=15);
plt.ylabel('continent',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 27. - Зависимость средней цены от континента", fontsize=15 );

# %%
data = df['price']

# %%
import statistics
statistics.pvariance(data)
# Out:
# 1848.1225780210896

# %%
continent= df.groupby('country_to_continent').agg({'price': ['mean','median', 'var','std','sem']})
#adding columns on numbers of reviews
continent['Counts'] =df['country_to_continent'].value_counts()
#creating dataframe
continent_plot = pd.DataFrame(continent).reset_index()
continent_plot = continent_plot.sort_values(("price","mean"), ascending=False)
continent_plot
# Out:
#   country_to_continent      price                                           \
#                              mean median          var        std       sem
# 2               Europe  41.125000   25.0  4325.153779  65.765901  0.986982
# 4        North America  34.187509   28.0   563.691807  23.742195  0.291255
# 1                 Asia  31.541667   25.0   367.941901  19.181812  2.260598
# 5              Oceania  28.614532   20.0   850.404869  29.161702  1.023375
# 0               Africa  22.264151   18.0   198.678709  14.095344  0.968072
# 3        Latin America  21.485904   15.0   480.930507  21.930128  0.631491
#
#   Counts
#
# 2   4440
# 4   6645
# 1     72
# 5    812
# 0    212
# 3   1206

# %%
continent_plot.mean()
# Out:
# price   mean        29.869794
#         median      21.833333
#         var       1131.133595
#         std         28.979514
#         sem          1.026962
# Counts            2231.166667
# dtype: float64

# %% [markdown]
# ТОП-5 стран с самым высоким средним значением цены

# %%
top_5 = df.groupby('country_to_continent').mean().sort_values(by = ['price'],ascending = False)
top_5 = pd.DataFrame(top_5.iloc[0:5,1])
top_5['Index'] = list(range(5))
top_5['country_to_continent'] = top_5.index.values
top_5.set_index(['Index'],inplace = True)
top_5
# Out:
#            price country_to_continent
# Index
# 0      41.125000               Europe
# 1      34.187509        North America
# 2      31.541667                 Asia
# 3      28.614532              Oceania
# 4      22.264151               Africa

# %%
country_continent = top_5.groupby(['country_to_continent',]).mean()['price'].sort_values(ascending = False).to_frame()
plt.figure(figsize=(10,10))
sns.pointplot(x = country_continent.price ,y = country_continent.index, color='maroon', orient='h')
plt.title('Средняя цена по континентам',fontsize=15)
plt.xlabel('price',fontsize=15);
plt.ylabel('continent',fontsize=15);
plt.figtext(0.2,0 , "Рисунок 28. - Зависимость средней цены от континента", fontsize=15 );

# %% [markdown]
# Дисперсия В теории вероятностей и статистике дисперсия - это математическое ожидание квадрата отклонения случайной величины от ее среднего или выборочного среднего. Дисперсия - это мера дисперсии, то есть мера того, насколько далеко набор чисел разбросан от их среднего значения. Дисперсия играет центральную роль в статистике, где некоторые идеи, которые ее используют, включают описательную статистику, статистический вывод, проверку гипотез, соответствие и выборку Монте-Карло. Дисперсия является важным инструментом в науках, где статистический анализ данных является общим. Дисперсия - это квадрат стандартного отклонения

# %%
import statistics
statistics.pvariance(data)
# Out:
# 1848.1225780210896

# %% [markdown]
# Стандартное отклонение(стандартное отклонение указывает на то, что точки данных могут распространяться далеко от среднего значения, а небольшое стандартное отклонение указывает на то, что они тесно сгруппированы вокруг среднего значения)

# %%
import statistics
statistics.pstdev(data)
# Out:
# 42.98979620818282

# %%
continent_plot.mean()
# Out:
# price   mean        29.869794
#         median      21.833333
#         var       1131.133595
#         std         28.979514
#         sem          1.026962
# Counts            2231.166667
# dtype: float64

# %% [markdown]
# Влияет ли рейтинг на цены по регионам?

# %% [markdown]
# Построим линейную регрессию зависимости между ценой продукта и его рейтингом

# %%
from scipy.stats.stats import pearsonr
y = pearsonr(df["price"], df["points"]) 
y
# Out:
# (0.4189486536141557, 0.0)

# %%
from scipy.stats.stats import pearsonr
y = pearsonr(df["points"], df["price"]) 
y
# Out:
# (0.4189486536141557, 0.0)

# %%
X = df[['price']]
X.shape
# Out:
# (13387, 1)

# %%
X = df[['price']].copy()
y = df[['points']].copy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Создадим модель линейной регрессии между ценой продукта и его рейтингом

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)
w = model.coef_
b = model.intercept_
print(w, b)
# Out:
# [[0.03265446]] [86.73508034]

# %% [markdown]
# Построим график зависимости цены от рейтинга и модель линейной регрессии

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X, y, label='real')
plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.plot(X_test.squeeze(), y_predicted.squeeze(), label='predicted')
plt.legend()
plt.ylim(80,102)
plt.title("Зависимость цены от рейтинга",fontsize=15)
plt.ylabel('points',fontsize=10);
plt.xlabel('price',fontsize=10);
plt.figtext(0.2, 0, "Рисунок 29. Линейная корреляция цены от качества",fontsize=15);
plt.show()

# %% [markdown]
# Видно, что цены на вина с одинаковой оценкой все еще сильно различаются, особенно разница в цене на вина с более высокими оценками. Также из рисунка видно, что есть несколько выбросов, большинство из них очень дорогие!

# %% [markdown]
# Выполним повторную выборку для значений log(price), посмотрим как изменится график

# %%
X = np.log(df[['price']].copy())
y = df[['points']].copy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Создадим модель линейной регрессии

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted = model.predict(X_test)
w = model.coef_
b = model.intercept_
print(w, b)
# Out:
# [[2.99434465]] [78.05653503]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X, y, label='real')
plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.plot(X_test.squeeze(), y_predicted.squeeze(), label='predicted')
plt.title("Зависимость цены от рейтинга",fontsize=15)
plt.ylabel('points',fontsize=10);
plt.xlabel('price',fontsize=10);
plt.figtext(0.2, -0, "Рисунок 30. Линейная корреляция Log(цены) от качества вина",fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# Существует корреляция между точками, данными вину, и логорифмом цены вина. Линейная комбинация переменных может дать прямую линию, но эта линия не соответствует данным. Но одна из тенденций заключается в том, что чем больше очков, тем больше цена вина.

# %% [markdown]
# Выведем значения MSE, MAE, R^2, RMSE

# %% [markdown]
# Среднеквадратичная ошибка (Mean Squared Error) – Среднее арифметическое (Mean) квадратов разностей между предсказанными и реальными значениями Модели (Model) Машинного обучения (ML): MSE как среднее дистанций между предсказаниями и реальными наблюдениями.Это всегда неотрицательно, и значения, близкие к нулю, лучше.

# %%
from sklearn.metrics import mean_squared_error
y_train_predicted = model.predict(X_train)
y_test_predicted = model.predict(X_test)
print('Train MSE: ', mean_squared_error(y_train, y_train_predicted))
print('Test MSE: ', mean_squared_error(y_test, y_test_predicted))
# Out:
# Train MSE:  6.708901901632353
# Test MSE:  6.723946088344079

# %% [markdown]
# Средняя абсолютная ошибка (Mean Absolute Error, MAE). Вычисляется как средняя абсолютная разность между значениями подгонки модели (на один шаг впереди в прогнозе по выборке) и наблюдаемыми хронологическими данными.

# %%
from sklearn.metrics import mean_absolute_error
print('Train MAE: ', mean_absolute_error(y_train, y_train_predicted))
print('Test MAE: ', mean_absolute_error(y_test, y_test_predicted))
# Out:
# Train MAE:  2.0645142553537466
# Test MAE:  2.083826269257661

# %% [markdown]
# Оценка R2 – это один из показателей оценки эффективности моделей машинного обучения на основе регрессии. Она также известна как коэффициент детерминации. Значение R2 должно находиться в диапазоне от нуля до единицы: 0 ≤ R2 ≤ 1. Модель считается более качественной, если значение коэффициента детерминации близко к 1. Если R2=1, то эмпирические точки (xi; yi) лежат точно на линии регрессии и между переменными Y и Х существует линейная функциональная зависимость. Если R2=0, то вариация зависимой переменной полностью обусловлена неучтенными в модели факторами.

# %%
from sklearn.metrics import r2_score
print('Train R^2: ', r2_score(y_train, y_train_predicted))
print('Test R^2: ', r2_score(y_test, y_test_predicted))
# Out:
# Train R^2:  0.3758803669064724
# Test R^2:  0.3908344404539882

# %% [markdown]
# Среднеквадратичная ошибка (RMSE) - это квадратный корень из среднего квадрата всей ошибки. RMSE считается отличной метрикой ошибок общего назначения для численных прогнозов. RMSE является хорошим показателем точности, но только для сравнения ошибок прогнозирования разных моделей или конфигураций моделей для конкретной переменной, а не между переменными, поскольку он зависит от масштаба. Это показатель того, насколько хорошо линия регрессии соответствует точкам данных

# %%
import math
MSE = mean_squared_error(y_train, y_train_predicted)
MSE1 = mean_squared_error(y_test, y_test_predicted)
RMSE = math.sqrt(mean_squared_error(y_train, y_train_predicted))
RMSE1 = math.sqrt(mean_squared_error(y_train, y_train_predicted))

# %%
print('Train RMSE: ', RMSE)
print('Test RMSE: ', RMSE1)
# Out:
# Train RMSE:  2.590154802638706
# Test RMSE:  2.590154802638706

# %% [markdown]
# #  <a name="5">5. Проверка гипотез </a>

# %% [markdown]
# Проверка гипотез H0: Средние пользовательские рейтинги красного и белого вина одинаковые. H1:Средние пользовательские рейтинги красного и белого вина разные. H0:Средние пользовательские рейтинги двух популярных сортов вина одинаковые. H1:Средние пользовательские рейтинги двух популярных сортов вина разные. H0:Средние пользовательские рейтинги двух континентов одинаковые. H1:Средние пользовательские рейтинги двух континентов разные. Задать самостоятельно пороговое значение alpha.

# %% [markdown]
# Проверим первую гипотезу

# %% [markdown]
# H0: Средние пользовательские рейтинги красного и белого вина одинаковые H1: Средние пользовательские рейтинги красного и белого вина разные

# %%
color_price = df.groupby(['color']).mean()['points'].sort_values(ascending=False).to_frame()
color_price
# Out:
#           points
# color
# red    88.046395
# white  87.632705
# other  87.323838

# %%
red = color_price.points[0]
red
# Out:
# 88.04639526950193

# %%
white = color_price.points[2]
white
# Out:
# 87.32383808095952

# %%
print('Средняя цена красного вина равна: ', red)
print('Средняя цена за бутылку белого вина : ', white)
# Out:
# Средняя цена красного вина равна:  88.04639526950193
# Средняя цена за бутылку белого вина :  87.32383808095952

# %%
if red == white:
    print('True')
else:
    print('False')
# Out:
# False

# %%
red = df[df.color == 'red']['points']
white = df[df.color == 'white']['points']

# %%
if np.var(red)==np.var(white ): #Выясним равны ли дисперсии двух массивов?
    print('True')
else:
    print('False')
# Out:
# False

# %%
sns.distplot(red, color='b')
plt.title("Статистическая гипотеза",fontsize=15)
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.2, -0.1, "Рисунок 31. Гистограмма и график плотности распределения оценок краcного вина",fontsize=20)
plt.show()
sns.distplot(white , color='y')
plt.title("Статистическая гипотеза",fontsize=15)
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.2, -0.1, "Рисунок 32. Гистограмма и график плотности распределения оценок белого вина",fontsize=20)
plt.show()
plt.show()

# %% [markdown]
# Вывод: Средние пользовательские рейтинги красного и белого вина разные.

# %%
alpha = .05 # критический уровень статистической значимости
 # если p-значение меньше альфа, мы отвергаем гипотезу
from scipy import stats as st
import scipy
results = scipy.stats.ttest_ind(red, white, equal_var = False)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отклоняем нулевую гипотезу")
else:
    print("Не получилось отклонить нулевую гипотезу")
# Out:
# p-значение: 1.884404141077982e-11
# Отклоняем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги красного и белого вина разные.

# %% [markdown]
# Проверим вторую гипотезу

# %% [markdown]
# H0:Средние пользовательские рейтинги двух популярных сортов вина одинаковые. H1:Средние пользовательские рейтинги двух популярных сортов вина разные.

# %%
top_10 = df.variety.value_counts().head(10) # Определим top_10 марок вин, общее количество 
top_10
# Out:
# Pinot Noir                  1660
# Chardonnay                  1588
# Cabernet Sauvignon          1462
# Red Blend                   1084
# Sauvignon Blanc              729
# Syrah                        652
# Riesling                     630
# Merlot                       571
# Bordeaux-style Red Blend     542
# Zinfandel                    461
# Name: variety, dtype: int64

# %%
print('Средний рейтинг вина Pinot Noir равен: ',df[df['variety']=='Pinot Noir']['points'].mean())
print('Средний рейтинг вина Chardonnay равен: ',df[df['variety']=='Chardonnay']['points'].mean())
# Out:
# Средний рейтинг вина Pinot Noir равен:  88.76084337349397
# Средний рейтинг вина Chardonnay равен:  87.68136020151134

# %%
Pinot = df[df.variety == 'Pinot Noir']['points']
Chard = df[df.variety == 'Chardonnay']['points']

# %%
if np.var(Pinot) == np.var(Chard):
    print('True')
else:
    print('False')
# Out:
# False

# %%
sns.distplot(Pinot, color='b')
plt.title("Статистическая гипотеза",fontsize=15);
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.1, -0.1, "Рисунок 33. Гистограмма и график плотности распределения рейтинга Pinot Noir",fontsize=15)
plt.show()
plt.show()
sns.distplot(Chard , color='y')
plt.title("Статистическая гипотеза",fontsize=15)
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.2, -0.1, "Рисунок 34. Гистограмма и график плотности распределения Chardonnay",fontsize=15)
plt.show()

# %% [markdown]
# Вывод: Средние пользовательские рейтинги двух популярных сортов вина разные.

# %%
alpha = .05
from scipy import stats as st
import scipy
results = scipy.stats.ttest_ind(Pinot, Chard, equal_var = False)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отклоняем нулевую гипотезу")
else:
    print("Не получилось отклонить нулевую гипотезу")
# Out:
# p-значение: 1.828141463141144e-19
# Отклоняем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги двух популярных сортов вина Pinot Noir и Chardonnay разные.

# %% [markdown]
# Проверим третью гипотезу

# %% [markdown]
# H0:Средние пользовательские рейтинги двух континентов одинаковые. H1:Средние пользовательские рейтинги двух континентов разные.

# %%
points_continent = df.groupby(['country_to_continent']).mean()['points'].sort_values(ascending=False).to_frame()
points_continent
# Out:
#                          points
# country_to_continent
# Europe                88.367793
# North America         87.899925
# Oceania               87.884236
# Asia                  87.250000
# Africa                87.165094
# Latin America         86.235489

# %%
print('Средний пользовательский рейтинг Europe равен: ', points_continent.points[0])
print('Средний пользовательский рейтинг North America равен: ', points_continent.points[1])
# Out:
# Средний пользовательский рейтинг Europe равен:  88.3677927927928
# Средний пользовательский рейтинг North America равен:  87.89992475545523

# %%
Europe = df[df.country_to_continent == 'Europe']['points']
North = df[df.country_to_continent == 'North America']['points']

# %%
if np.var(Europe) == np.var(North):
    print('True')
else:
    print('False')
# Out:
# False

# %%
sns.distplot(Europe, color='b')
plt.title("Статистическая гипотеза",fontsize=15)
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.2, -0.1, "Рисунок 35. Гистограмма и график плотности распределения оценок Europe",fontsize=15)
plt.show()
sns.distplot(North , color='y')
plt.title("Статистическая гипотеза",fontsize=15)
plt.ylabel('частота',fontsize=10);
plt.xlabel('points',fontsize=10);
plt.figtext(0.2, -0.1, "Рисунок 36. Гистограмма и график плотности распределения оценок North America",fontsize=15)
plt.show()

# %%
alpha = .05
from scipy import stats as st
import scipy
results = scipy.stats.ttest_ind(Pinot, Chard, equal_var = False)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отклоняем нулевую гипотезу")
else:
    print("Не получилось отклонить нулевую гипотезу")
# Out:
# p-значение: 1.828141463141144e-19
# Отклоняем нулевую гипотезу

# %% [markdown]
# Вывод: Средние пользовательские рейтинги двух континентов Europe и North America разные.

# %% [markdown]
# # <a name="6">6. Выводы</a>

# %% [markdown]
# В Латинской Америке самые низкие средние цены и рейтинги, в Европе самые высокие. Скорее всего это связано с требованиями по качеству вина в данных континентах и с уровнем жизни.Так же спрос формирует цену. Цена будет расти, пока за продукт готовы ее платить. Вот почему «топовые» винтажи могут стоить от 2300 $ за бутылку. в Америе и Европе самые высокие средние рейтинги и цены, в Латинской Америке и Африке самые низкие.

# %% [markdown]
# В наборе данных к данному проекту США занимает более 50%, далее идет Франция, Италия, Чили. Такая тенденция может быть объяснена тем, что набор данных был подготовлоен журналом из США. Не отображена полная статистика из Китая и России. Эти две страны являются крупными производителями и потребителями вина в мире.

# %% [markdown]
# Видно что первые 3 строчки рейтинга с максимальной средней стоимостью вина занимают страны Европейского континентаю. Самая высокая средняя цена в Турции, Франции и Италии. Далее идет Канада

# %% [markdown]
# Самая низкая цена вина в Australia, стоимость бутылки 5 долларов США. Самая высокая во Франции - 2300 долларов США.

# %% [markdown]
# Определили, что цены на вина с одинаковой оценкой все еще сильно различаются, особенно разница в цене на вина с более высокими оценками. В статистике данных есть несколько выбросов, большинство из них очень дорогие! Есть определённая зависимость между рейтингом вина и ценой. При увеличении цены увеличивается рейтинг. Но это происходит не всегда. Рейтинг не влияет на цены вина.

# %% [markdown]
# Самые популярные марки вина в мире Pinot Noir и Chardonnay, самые дорогие "Bordeaux-style Red Blend" - 2300 долларов США и Chardonnay - 2013 долларов США, самые дешёвые Zinfandel,Cabernet Sauvignon,Malbec. Пино Нуар является самым распространенным видом винограда. Средний рейтинг вина самый высокий в мире у Pinot Noir и Chardonnay.

# %% [markdown]
# Существует корреляция между точками, данными вину, и логорифмом цены вина. Линейная комбинация переменных может дать прямую линию, но эта линия не соответствует данным. Но одна из тенденций заключается в том, что чем больше очков, тем больше цена вина.

# %% [markdown]
# В производстве самые популярные вина красные и белые. Красное вино и белое вино массово производится в США 53% и 46% соответсвенно. Самое популярное конечно же красное вино которое упоминается в данных 8794 раз и белое 3926 раз другие марки вин составляют 667.

# %% [markdown]
# Выяснили, что средние пользовательские рейтинги двух континентов Europы и North America, рейтинги двух популярных сортов вина Pinot Noir и Chardonnay и рейтинги красного и белого вина разные.

# %% [markdown]
# Pinot Noir красное упоминается в данных 1660 раз, Chardonnay white - 1588, Cabernet Sauvignon red - 1462, Red Blend red - 1084. Такая популярность обусловлена большим производством данных вин и популярностью данных сортов.

# %% [markdown]
# Самые популярные оценки качества вин так же принадлежат Pinot Noir с оценкой - 87 баллов упоминается - 150 раза, на втором месте Cabernet Sauvignon с оценкой - 90 баллов оценено 141 раз.
